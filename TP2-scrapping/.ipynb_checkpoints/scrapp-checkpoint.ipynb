# %%
"""
Scraping de synopsis de films d'horreur depuis Wikipédia (fr)

Ce script télécharge automatiquement les résumés (sections "Synopsis") de pages Wikipédia
pour une liste de films d'horreur. Les textes récupérés sont nettoyés et sauvegardés
dans des fichiers `.txt`, un par film, dans un dossier local.

Fonctionnalités :
-----------------
1. Accès automatisé aux pages Wikipédia en français pour chaque film.
2. Extraction de la section "Synopsis" si elle est présente.
   - Sinon, extraction du contenu général des paragraphes de la page.
3. Nettoyage du texte (suppression des références [1], [2], etc.).
4. Sauvegarde des synopsis dans un dossier local `film_synopses/`.

Dépendances :
-------------
- `requests` : pour effectuer les requêtes HTTP
- `BeautifulSoup` (`bs4`) : pour parser le HTML
- `re` : pour les expressions régulières
- `os`, `time` : pour la gestion de fichiers et des temps d’exécution

Utilisation :
-------------
- La liste de films est personnalisable dans `films_horreur` (format URL Wikipédia).
- Le script crée un fichier `.txt` par film contenant son synopsis.

Limitations :
-------------
- Certaines pages Wikipédia peuvent ne pas contenir la section "Synopsis".
- Des pages mal formatées ou trop courtes peuvent générer des textes incomplets.
- Risque de blocage temporaire si trop de requêtes en peu de temps (Wikipédia).

Conseils :
----------
- Pour des corpus volumineux, introduire un `time.sleep()` entre les requêtes.
- Vérifier manuellement les cas où le texte retourné est vide ou erroné.
- Utiliser des titres Wikipédia exacts (pas forcément les titres en français courant).

"""

import requests
from bs4 import BeautifulSoup
import time
import re
import os

# Liste des films d'horreur
films_horreur = [
    "The_Strangers_(film,_2016)", "It_Comes_at_Night", "Ça_(film,_2017)", "The_Witch_(film,_2015)", "Paranormal_Activity", "The_Grudge_3", 
    "Evil_Dead_(film,_2013)", "L'Exorciste_(film)", "Annabelle_(film)", "Ouija_(film,_2014)", "Le_Cercle_(film,_2002)",
    "Terrifier_2", "Scream_(film,_2022)", "The_Sadness","Us_(film,_2019)","Hérédité_(film,_2018)","Slender_Man_(film)"
    "The_Descent", "Insidious_:_Chapitre_2", "The_Grudge", "Saw", "Poltergeist", "Sinister","Le_Rituel_(film)","Le_Secret_des_Marrowbone"
    "It_Follows", "Cabin_in_the_Woods", "The_Visit", "Hellraiser_(film,_2022)", "It_Chapter_Two", "Friday_the_13th", 
      "An_American_Werewolf_in_London","Immaculée","Smile_(film,_2022)","Evil_Dead_Rise","Halloween_(film,_2018)","The_Babysitter_(film,_2017)",
    "Chucky_3","Poltergeist_(film,_1982)","The_Mirror_(film,_2013)","Conjuring_2_:_Le_Cas_Enfield","American_Nightmare_(film,_2013)",
    "Carrie_:_La_Vengeance","Possédée","La_Cabane_dans_les_bois","Antichrist_(film)","Midsommar_(film)","Cloverfield","Underworld_(film,_2003)",
    "Resident_Evil:_Apocalypse","L'Exorciste_du_Vatican","Brightburn_:_L'Enfant_du_mal","Escape_Game_(film)","Get_Out_(film)"
    
]

def get_movie_synopsis(movie_name):
    # Construire l'URL de la page Wikipédia du film
    url = f'https://fr.wikipedia.org/wiki/{movie_name}'
    
    # Démarrer le chronomètre pour mesurer le temps de la requête
    start_time = time.time()

    # Faire une requête HTTP GET pour récupérer le contenu de la page
    response = requests.get(url)

    # Vérifier si la requête a réussi (code de statut 200 signifie succès)
    if response.status_code == 200:
        print(f"Page fetched for {movie_name} in {time.time() - start_time} seconds")
    else:
        print(f"Unable to download the page for {movie_name}")
        return None  # Retourner seulement None si l'extraction échoue

    # Analyser le contenu de la page avec BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')

    # Recherche de la section "Synopsis"
    synopsis_section = soup.find('span', {'id': 'Synopsis'})
    cleaned_synopsis = ""
    if synopsis_section:
        next_paragraphs = synopsis_section.find_all_next('p')
        synopsis = ""
        for p in next_paragraphs:
            synopsis += p.get_text().strip() + " "
        cleaned_synopsis = re.sub(r'\[[^\]]*\]', '', synopsis)  # Supprimer les références comme [1], [2], etc.
    
    # Si la section "Synopsis" n'est pas trouvée, essayer de récupérer les paragraphes suivants l'intro comme synopse
    if not cleaned_synopsis:
        # Extraire un autre bloc de texte comme synopse
        paragraphs = soup.find_all('p')
        synopsis = ""
        for p in paragraphs:
            synopsis += p.get_text().strip() + " "
        cleaned_synopsis = re.sub(r'\[[^\]]*\]', '', synopsis)  # Supprimer les références comme [1], [2], etc.

    # Retourner la synopse nettoyée
    return cleaned_synopsis

# Créer un dossier pour stocker les fichiers si nécessaire
output_folder = 'film_synopses'
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Parcourir chaque film dans la liste
for movie in films_horreur:
    print(f"\nFetching synopsis for: {movie}")
    synopsis = get_movie_synopsis(movie)
    
    # Assurer qu'on a bien reçu la synopse
    if synopsis:
        # Utiliser le titre du film pour créer un nom de fichier valide
        file_name = f"{output_folder}/{movie.replace(' ', '_')}.txt"
        
        # Enregistrer la synopse dans un fichier texte
        with open(file_name, 'w', encoding='utf-8') as f:
            f.write(f"Synopsis: {synopsis}\n")
        
        print(f"Synopsis for {movie} saved in: {file_name}")
    

# Aide de ce site: https://rayobyte.com/community/scraping-project/scraping-wikipedia-with-python-extract-articles-and-metadata/
# Out:
# Fetching synopsis for: The_Strangers_(film,_2016)
# Page fetched for The_Strangers_(film,_2016) in 0.12841033935546875 seconds
# Synopsis for The_Strangers_(film,_2016) saved in: film_synopses/The_Strangers_(film,_2016).txt
#
# Fetching synopsis for: It_Comes_at_Night
# Page fetched for It_Comes_at_Night in 0.14527606964111328 seconds
# Synopsis for It_Comes_at_Night saved in: film_synopses/It_Comes_at_Night.txt
#
# Fetching synopsis for: Ça_(film,_2017)
# Page fetched for Ça_(film,_2017) in 0.18231868743896484 seconds
# Synopsis for Ça_(film,_2017) saved in: film_synopses/Ça_(film,_2017).txt
#
# Fetching synopsis for: The_Witch_(film,_2015)
# Page fetched for The_Witch_(film,_2015) in 0.15666961669921875 seconds
# Synopsis for The_Witch_(film,_2015) saved in: film_synopses/The_Witch_(film,_2015).txt
#
# Fetching synopsis for: Paranormal_Activity
# Page fetched for Paranormal_Activity in 0.1390671730041504 seconds
# Synopsis for Paranormal_Activity saved in: film_synopses/Paranormal_Activity.txt
#
# Fetching synopsis for: The_Grudge_3
# Page fetched for The_Grudge_3 in 0.11169290542602539 seconds
# Synopsis for The_Grudge_3 saved in: film_synopses/The_Grudge_3.txt
#
# Fetching synopsis for: Evil_Dead_(film,_2013)
# Page fetched for Evil_Dead_(film,_2013) in 0.11590790748596191 seconds
# Synopsis for Evil_Dead_(film,_2013) saved in: film_synopses/Evil_Dead_(film,_2013).txt
#
# Fetching synopsis for: L'Exorciste_(film)
# Page fetched for L'Exorciste_(film) in 0.15892314910888672 seconds
# Synopsis for L'Exorciste_(film) saved in: film_synopses/L'Exorciste_(film).txt
#
# Fetching synopsis for: Annabelle_(film)
# Page fetched for Annabelle_(film) in 0.27754735946655273 seconds
# Synopsis for Annabelle_(film) saved in: film_synopses/Annabelle_(film).txt
#
# Fetching synopsis for: Ouija_(film,_2014)
# Page fetched for Ouija_(film,_2014) in 0.15305542945861816 seconds
# Synopsis for Ouija_(film,_2014) saved in: film_synopses/Ouija_(film,_2014).txt
#
# Fetching synopsis for: Le_Cercle_(film,_2002)
# Page fetched for Le_Cercle_(film,_2002) in 0.19436359405517578 seconds
# Synopsis for Le_Cercle_(film,_2002) saved in: film_synopses/Le_Cercle_(film,_2002).txt
#
# Fetching synopsis for: Terrifier_2
# Page fetched for Terrifier_2 in 0.11059808731079102 seconds
# Synopsis for Terrifier_2 saved in: film_synopses/Terrifier_2.txt
#
# Fetching synopsis for: Scream_(film,_2022)
# Page fetched for Scream_(film,_2022) in 0.16771292686462402 seconds
# Synopsis for Scream_(film,_2022) saved in: film_synopses/Scream_(film,_2022).txt
#
# Fetching synopsis for: The_Sadness
# Page fetched for The_Sadness in 0.10500764846801758 seconds
# Synopsis for The_Sadness saved in: film_synopses/The_Sadness.txt
#
# Fetching synopsis for: Us_(film,_2019)
# Page fetched for Us_(film,_2019) in 0.166306734085083 seconds
# Synopsis for Us_(film,_2019) saved in: film_synopses/Us_(film,_2019).txt
#
# Fetching synopsis for: Hérédité_(film,_2018)
# Page fetched for Hérédité_(film,_2018) in 0.18589329719543457 seconds
# Synopsis for Hérédité_(film,_2018) saved in: film_synopses/Hérédité_(film,_2018).txt
#
# Fetching synopsis for: Slender_Man_(film)The_Descent
# Unable to download the page for Slender_Man_(film)The_Descent
#
# Fetching synopsis for: Insidious_:_Chapitre_2
# Page fetched for Insidious_:_Chapitre_2 in 0.1511552333831787 seconds
# Synopsis for Insidious_:_Chapitre_2 saved in: film_synopses/Insidious_:_Chapitre_2.txt
#
# Fetching synopsis for: The_Grudge
# Page fetched for The_Grudge in 0.14539456367492676 seconds
# Synopsis for The_Grudge saved in: film_synopses/The_Grudge.txt
#
# Fetching synopsis for: Saw
# Page fetched for Saw in 0.28317713737487793 seconds
# Synopsis for Saw saved in: film_synopses/Saw.txt
#
# Fetching synopsis for: Poltergeist
# Page fetched for Poltergeist in 0.3317098617553711 seconds
# Synopsis for Poltergeist saved in: film_synopses/Poltergeist.txt
#
# Fetching synopsis for: Sinister
# Page fetched for Sinister in 0.2163410186767578 seconds
# Synopsis for Sinister saved in: film_synopses/Sinister.txt
#
# Fetching synopsis for: Le_Rituel_(film)
# Page fetched for Le_Rituel_(film) in 0.1577751636505127 seconds
# Synopsis for Le_Rituel_(film) saved in: film_synopses/Le_Rituel_(film).txt
#
# Fetching synopsis for: Le_Secret_des_MarrowboneIt_Follows
# Unable to download the page for Le_Secret_des_MarrowboneIt_Follows
#
# Fetching synopsis for: Cabin_in_the_Woods
# Unable to download the page for Cabin_in_the_Woods
#
# Fetching synopsis for: The_Visit
# Page fetched for The_Visit in 0.09255814552307129 seconds
# Synopsis for The_Visit saved in: film_synopses/The_Visit.txt
#
# Fetching synopsis for: Hellraiser_(film,_2022)
# Page fetched for Hellraiser_(film,_2022) in 0.1269841194152832 seconds
# Synopsis for Hellraiser_(film,_2022) saved in: film_synopses/Hellraiser_(film,_2022).txt
#
# Fetching synopsis for: It_Chapter_Two
# Unable to download the page for It_Chapter_Two
#
# Fetching synopsis for: Friday_the_13th
# Page fetched for Friday_the_13th in 0.10037589073181152 seconds
# Synopsis for Friday_the_13th saved in: film_synopses/Friday_the_13th.txt
#
# Fetching synopsis for: An_American_Werewolf_in_London
# Page fetched for An_American_Werewolf_in_London in 0.15981006622314453 seconds
# Synopsis for An_American_Werewolf_in_London saved in: film_synopses/An_American_Werewolf_in_London.txt
#
# Fetching synopsis for: Immaculée
# Page fetched for Immaculée in 0.15405654907226562 seconds
# Synopsis for Immaculée saved in: film_synopses/Immaculée.txt
#
# Fetching synopsis for: Smile_(film,_2022)
# Page fetched for Smile_(film,_2022) in 0.13469481468200684 seconds
# Synopsis for Smile_(film,_2022) saved in: film_synopses/Smile_(film,_2022).txt
#
# Fetching synopsis for: Evil_Dead_Rise
# Page fetched for Evil_Dead_Rise in 0.15731024742126465 seconds
# Synopsis for Evil_Dead_Rise saved in: film_synopses/Evil_Dead_Rise.txt
#
# Fetching synopsis for: Halloween_(film,_2018)
# Page fetched for Halloween_(film,_2018) in 0.12592220306396484 seconds
# Synopsis for Halloween_(film,_2018) saved in: film_synopses/Halloween_(film,_2018).txt
#
# Fetching synopsis for: The_Babysitter_(film,_2017)
# Page fetched for The_Babysitter_(film,_2017) in 0.13373780250549316 seconds
# Synopsis for The_Babysitter_(film,_2017) saved in: film_synopses/The_Babysitter_(film,_2017).txt
#
# Fetching synopsis for: Chucky_3
# Page fetched for Chucky_3 in 0.11153936386108398 seconds
# Synopsis for Chucky_3 saved in: film_synopses/Chucky_3.txt
#
# Fetching synopsis for: Poltergeist_(film,_1982)
# Page fetched for Poltergeist_(film,_1982) in 0.15393924713134766 seconds
# Synopsis for Poltergeist_(film,_1982) saved in: film_synopses/Poltergeist_(film,_1982).txt
#
# Fetching synopsis for: The_Mirror_(film,_2013)
# Page fetched for The_Mirror_(film,_2013) in 0.1313178539276123 seconds
# Synopsis for The_Mirror_(film,_2013) saved in: film_synopses/The_Mirror_(film,_2013).txt
#
# Fetching synopsis for: Conjuring_2_:_Le_Cas_Enfield
# Page fetched for Conjuring_2_:_Le_Cas_Enfield in 0.1675281524658203 seconds
# Synopsis for Conjuring_2_:_Le_Cas_Enfield saved in: film_synopses/Conjuring_2_:_Le_Cas_Enfield.txt
#
# Fetching synopsis for: American_Nightmare_(film,_2013)
# Page fetched for American_Nightmare_(film,_2013) in 0.11771821975708008 seconds
# Synopsis for American_Nightmare_(film,_2013) saved in: film_synopses/American_Nightmare_(film,_2013).txt
#
# Fetching synopsis for: Carrie_:_La_Vengeance
# Page fetched for Carrie_:_La_Vengeance in 0.12101101875305176 seconds
# Synopsis for Carrie_:_La_Vengeance saved in: film_synopses/Carrie_:_La_Vengeance.txt
#
# Fetching synopsis for: Possédée
# Page fetched for Possédée in 0.11478757858276367 seconds
# Synopsis for Possédée saved in: film_synopses/Possédée.txt
#
# Fetching synopsis for: La_Cabane_dans_les_bois
# Page fetched for La_Cabane_dans_les_bois in 0.11104297637939453 seconds
# Synopsis for La_Cabane_dans_les_bois saved in: film_synopses/La_Cabane_dans_les_bois.txt
#
# Fetching synopsis for: Antichrist_(film)
# Page fetched for Antichrist_(film) in 0.14149761199951172 seconds
# Synopsis for Antichrist_(film) saved in: film_synopses/Antichrist_(film).txt
#
# Fetching synopsis for: Midsommar_(film)
# Page fetched for Midsommar_(film) in 0.18139910697937012 seconds
# Synopsis for Midsommar_(film) saved in: film_synopses/Midsommar_(film).txt
#
# Fetching synopsis for: Cloverfield
# Page fetched for Cloverfield in 0.1290757656097412 seconds
# Synopsis for Cloverfield saved in: film_synopses/Cloverfield.txt
#
# Fetching synopsis for: Underworld_(film,_2003)
# Page fetched for Underworld_(film,_2003) in 0.20060157775878906 seconds
# Synopsis for Underworld_(film,_2003) saved in: film_synopses/Underworld_(film,_2003).txt
#
# Fetching synopsis for: Resident_Evil:_Apocalypse
# Page fetched for Resident_Evil:_Apocalypse in 0.11605191230773926 seconds
# Synopsis for Resident_Evil:_Apocalypse saved in: film_synopses/Resident_Evil:_Apocalypse.txt
#
# Fetching synopsis for: L'Exorciste_du_Vatican
# Page fetched for L'Exorciste_du_Vatican in 0.24280762672424316 seconds
# Synopsis for L'Exorciste_du_Vatican saved in: film_synopses/L'Exorciste_du_Vatican.txt
#
# Fetching synopsis for: Brightburn_:_L'Enfant_du_mal
# Page fetched for Brightburn_:_L'Enfant_du_mal in 0.14699697494506836 seconds
# Synopsis for Brightburn_:_L'Enfant_du_mal saved in: film_synopses/Brightburn_:_L'Enfant_du_mal.txt
#
# Fetching synopsis for: Escape_Game_(film)
# Page fetched for Escape_Game_(film) in 0.15023279190063477 seconds
# Synopsis for Escape_Game_(film) saved in: film_synopses/Escape_Game_(film).txt
#
# Fetching synopsis for: Get_Out_(film)
# Page fetched for Get_Out_(film) in 0.17506814002990723 seconds
# Synopsis for Get_Out_(film) saved in: film_synopses/Get_Out_(film).txt
